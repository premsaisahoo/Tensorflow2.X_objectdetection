# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.8.2

# %%
# %cd /content/drive/MyDrive/Tf2
# Out:
# /content/drive/MyDrive/Tf2

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 74612, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 74612 (delta 45), reused 73 (delta 28), pack-reused 74512
# Receiving objects: 100% (74612/74612), 580.30 MiB | 16.35 MiB/s, done.
# Resolving deltas: 100% (52915/52915), done.
# Checking out files: 100% (3075/3075), done.

# %%
# %%bash
# cd models/research/
# protoc object_detection/protos/*.proto --python_out=.

# %%
# %%bash
# cd models/research/object_detection/packages/tf2
# pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/drive/MyDrive/Tf2/models/research/object_detection/packages/tf2
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
# Collecting apache-beam
#   Downloading apache_beam-2.39.0-cp37-cp37m-manylinux2010_x86_64.whl (10.3 MB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (4.2.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.29.30)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.0.4)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.3.5)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.9.2-py2.py3-none-any.whl (2.1 MB)
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.26.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (25.9 MB)
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.8.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.17.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.12.11)
# Collecting sacrebleu
#   Downloading sacrebleu-2.1.0-py3-none-any.whl (92 kB)
# Collecting tensorflow~=2.9.0
#   Downloading tensorflow-2.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
# Collecting py-cpuinfo>=3.3.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.21.6)
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.2-py2.py3-none-any.whl (237 kB)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.0.1)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (48.3 MB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Collecting tensorflow-text~=2.9.0
#   Downloading tensorflow_text-2.9.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.17.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.31.6)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.2)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.23.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (21.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2022.1)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.17.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.2.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.6.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# Collecting keras
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (14.0.1)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.26.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.46.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.7)
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.5.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
# Collecting cloudpickle<3,>=2.0.0
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.12.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (508 kB)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Collecting proto-plus<2,>=1.7.1
#   Downloading proto_plus-1.20.6-py3-none-any.whl (46 kB)
# Collecting orjson<4.0
#   Downloading orjson-3.7.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (256 kB)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: pyarrow<8.0.0,>=0.15.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (6.0.1)
# Collecting requests<3.0.0dev,>=2.18.0
#   Downloading requests-2.28.0-py3-none-any.whl (62 kB)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Collecting protobuf<4.0.0dev,>=3.12.0
#   Downloading protobuf-3.19.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.0.12)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (1.4.3)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (4.1.2.30)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (0.8.9)
# Collecting colorama
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (2022.6.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.8.0)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (21.4.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.16.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.7.1)
# Building wheels for collected packages: object-detection, py-cpuinfo, dill, avro-python3, seqeval
#   Building wheel for object-detection (setup.py): started
#   Building wheel for object-detection (setup.py): finished with status 'done'
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1222 sha256=78a6acc0726887b3e5687b1ab7056f5d66bc06d6eea2849f2444b2e205d552ca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gn_1fhdp/wheels/30/a7/89/fe54e2686590c536f54ab20c19292a712b6206733de7fb6457
#   Building wheel for py-cpuinfo (setup.py): started
#   Building wheel for py-cpuinfo (setup.py): finished with status 'done'
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22257 sha256=f6e6a606ac223eb4a8e03c36222b1c3fac207be20f671ba2311f8e41ea46b7c0
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78544 sha256=d9d850e7f3cc55a798fd913ecf56406c17e729de25d259ed5983fcaadff39503
#   Stored in directory: /root/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for avro-python3 (setup.py): started
#   Building wheel for avro-python3 (setup.py): finished with status 'done'
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=44010 sha256=e6c3c21cd79abcf7283ec834a864d013dfd520abe398f3e2a9e5a3dcfb93045a
#   Stored in directory: /root/.cache/pip/wheels/d6/e5/b1/6b151d9b535ee50aaa6ab27d145a0104b6df02e5636f0376da
#   Building wheel for seqeval (setup.py): started
#   Building wheel for seqeval (setup.py): finished with status 'done'
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=8c9cec00d70bdd863fcb4ded0448da016854290ae2ccd0939bb8912b46fe6b3e
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built object-detection py-cpuinfo dill avro-python3 seqeval
# Installing collected packages: requests, pyparsing, protobuf, tensorflow-estimator, tensorboard, keras, gast, flatbuffers, tensorflow, portalocker, dill, colorama, tf-slim, tensorflow-text, tensorflow-model-optimization, tensorflow-addons, seqeval, sentencepiece, sacrebleu, pyyaml, pymongo, py-cpuinfo, proto-plus, orjson, opencv-python-headless, hdfs, fastavro, cloudpickle, tf-models-official, tensorflow-io, lvis, avro-python3, apache-beam, object-detection
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
#     Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220527125636
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.5.1
#     Uninstalling dill-0.3.5.1:
#       Successfully uninstalled dill-0.3.5.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.1.1
#     Uninstalling pymongo-4.1.1:
#       Successfully uninstalled pymongo-4.1.1
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
# Successfully installed apache-beam-2.39.0 avro-python3-1.10.2 cloudpickle-2.1.0 colorama-0.4.5 dill-0.3.1.1 fastavro-1.5.1 flatbuffers-1.12 gast-0.4.0 hdfs-2.7.0 keras-2.9.0 lvis-0.5.3 object-detection-0.1 opencv-python-headless-4.6.0.66 orjson-3.7.2 portalocker-2.4.0 proto-plus-1.20.6 protobuf-3.19.4 py-cpuinfo-8.0.0 pymongo-3.12.3 pyparsing-2.4.7 pyyaml-5.4.1 requests-2.28.0 sacrebleu-2.1.0 sentencepiece-0.1.96 seqeval-1.2.2 tensorboard-2.9.1 tensorflow-2.9.1 tensorflow-addons-0.17.1 tensorflow-estimator-2.9.0 tensorflow-io-0.26.0 tensorflow-model-optimization-0.7.2 tensorflow-text-2.9.0 tf-models-official-2.9.2 tf-slim-1.1.0
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# multiprocess 0.70.13 requires dill>=0.3.5.1, but you have dill 0.3.1.1 which is incompatible.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.1.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
# %cd models/research
# Out:
# /content/drive/MyDrive/Tf2/models/research

# %%
# !python xml_to_csv.py
# Out:
# Successfully converted xml to csv.
# Successfully converted xml to csv.

# %%
# !python generate_tfrecord.py --csv_input=images/train_labels.csv --image_dir=images/train --output_path=train.record
# Out:
# Successfully created the TFRecords: /content/drive/MyDrive/Tf2/models/research/train.record

# %%
# !python generate_tfrecord.py --csv_input=images/test_labels.csv --image_dir=images/test --output_path=test.record
# Out:
# Successfully created the TFRecords: /content/drive/MyDrive/Tf2/models/research/test.record

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Out:
# --2022-06-21 05:17:39--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.251.12.128, 2404:6800:4003:c11::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.251.12.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244817203 (233M) [application/x-tar]
# Saving to: ‘ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz’
#
# ssd_resnet50_v1_fpn 100%[===================>] 233.48M  61.8MB/s    in 4.0s
#
# 2022-06-21 05:17:44 (58.0 MB/s) - ‘ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz’ saved [244817203/244817203]

# %%
# !tar -xvf ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Out:
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/checkpoint
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/saved_model.pb
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/assets/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %%
# !mv ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config /content/drive/MyDrive/Tf2/models/research/training

# %%
# !python model_main_tf2.py --model_dir=models/my_model --pipeline_config_path=training/pipeline.config
# Out:
# 2022-06-21 05:51:04.388440: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0621 05:51:04.435506 140686958434176 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0621 05:51:04.441788 140686958434176 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0621 05:51:04.441964 140686958434176 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /content/drive/MyDrive/Tf2/models/research/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0621 05:51:04.596801 140686958434176 deprecation.py:343] From /content/drive/MyDrive/Tf2/models/research/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['train.record']
# I0621 05:51:04.617174 140686958434176 dataset_builder.py:162] Reading unweighted datasets: ['train.record']
# INFO:tensorflow:Reading record datasets for input file: ['train.record']
# I0621 05:51:04.617523 140686958434176 dataset_builder.py:79] Reading record datasets for input file: ['train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0621 05:51:04.617665 140686958434176 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0621 05:51:04.617737 140686958434176 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /content/drive/MyDrive/Tf2/models/research/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0621 05:51:04.623735 140686958434176 deprecation.py:343] From /content/drive/MyDrive/Tf2/models/research/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /content/drive/MyDrive/Tf2/models/research/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0621 05:51:04.660959 140686958434176 deprecation.py:343] From /content/drive/MyDrive/Tf2/models/research/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0621 05:51:11.311161 140686958434176 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0621 05:51:14.280963 140686958434176 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0621 05:51:15.974414 140686958434176 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0621 05:51:50.930560 140686958434176 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0621 05:51:50.931803 140686958434176 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0621 05:51:50.933931 140686958434176 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0621 05:51:50.934832 140686958434176 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0621 05:51:50.936984 140686958434176 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0621 05:51:50.937875 140686958434176 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0621 05:51:50.940372 140686958434176 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0621 05:51:50.941264 140686958434176 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0621 05:51:50.943402 140686958434176 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0621 05:51:50.944422 140686958434176 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0621 05:51:52.594254 140681727633152 deprecation.py:547] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.895s
# I0621 05:53:21.764661 140686958434176 model_lib_v2.py:707] Step 100 per-step time 0.895s
# INFO:tensorflow:{'Loss/classification_loss': 0.5670035,
#  'Loss/localization_loss': 0.24554384,
#  'Loss/regularization_loss': 0.26487446,
#  'Loss/total_loss': 1.0774218,
#  'learning_rate': 0.014666351}
# I0621 05:53:21.765138 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.5670035,
#  'Loss/localization_loss': 0.24554384,
#  'Loss/regularization_loss': 0.26487446,
#  'Loss/total_loss': 1.0774218,
#  'learning_rate': 0.014666351}
# INFO:tensorflow:Step 200 per-step time 0.558s
# I0621 05:54:17.333624 140686958434176 model_lib_v2.py:707] Step 200 per-step time 0.558s
# INFO:tensorflow:{'Loss/classification_loss': 0.3952134,
#  'Loss/localization_loss': 0.12841244,
#  'Loss/regularization_loss': 0.26654223,
#  'Loss/total_loss': 0.79016805,
#  'learning_rate': 0.0159997}
# I0621 05:54:17.333969 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.3952134,
#  'Loss/localization_loss': 0.12841244,
#  'Loss/regularization_loss': 0.26654223,
#  'Loss/total_loss': 0.79016805,
#  'learning_rate': 0.0159997}
# INFO:tensorflow:Step 300 per-step time 0.554s
# I0621 05:55:12.740623 140686958434176 model_lib_v2.py:707] Step 300 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.32736418,
#  'Loss/localization_loss': 0.1056142,
#  'Loss/regularization_loss': 0.26687497,
#  'Loss/total_loss': 0.69985336,
#  'learning_rate': 0.01733305}
# I0621 05:55:12.740992 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.32736418,
#  'Loss/localization_loss': 0.1056142,
#  'Loss/regularization_loss': 0.26687497,
#  'Loss/total_loss': 0.69985336,
#  'learning_rate': 0.01733305}
# INFO:tensorflow:Step 400 per-step time 0.558s
# I0621 05:56:08.515792 140686958434176 model_lib_v2.py:707] Step 400 per-step time 0.558s
# INFO:tensorflow:{'Loss/classification_loss': 0.23643872,
#  'Loss/localization_loss': 0.10543105,
#  'Loss/regularization_loss': 0.26669216,
#  'Loss/total_loss': 0.60856193,
#  'learning_rate': 0.0186664}
# I0621 05:56:08.516118 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.23643872,
#  'Loss/localization_loss': 0.10543105,
#  'Loss/regularization_loss': 0.26669216,
#  'Loss/total_loss': 0.60856193,
#  'learning_rate': 0.0186664}
# INFO:tensorflow:Step 500 per-step time 0.557s
# I0621 05:57:04.200009 140686958434176 model_lib_v2.py:707] Step 500 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.37268764,
#  'Loss/localization_loss': 0.13565822,
#  'Loss/regularization_loss': 0.26545024,
#  'Loss/total_loss': 0.7737961,
#  'learning_rate': 0.01999975}
# I0621 05:57:04.200395 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.37268764,
#  'Loss/localization_loss': 0.13565822,
#  'Loss/regularization_loss': 0.26545024,
#  'Loss/total_loss': 0.7737961,
#  'learning_rate': 0.01999975}
# INFO:tensorflow:Step 600 per-step time 0.557s
# I0621 05:57:59.876317 140686958434176 model_lib_v2.py:707] Step 600 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.33216536,
#  'Loss/localization_loss': 0.08552053,
#  'Loss/regularization_loss': 0.26365247,
#  'Loss/total_loss': 0.68133837,
#  'learning_rate': 0.0213331}
# I0621 05:57:59.876613 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.33216536,
#  'Loss/localization_loss': 0.08552053,
#  'Loss/regularization_loss': 0.26365247,
#  'Loss/total_loss': 0.68133837,
#  'learning_rate': 0.0213331}
# INFO:tensorflow:Step 700 per-step time 0.556s
# I0621 05:58:55.436796 140686958434176 model_lib_v2.py:707] Step 700 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.24528205,
#  'Loss/localization_loss': 0.1136791,
#  'Loss/regularization_loss': 0.26196855,
#  'Loss/total_loss': 0.6209297,
#  'learning_rate': 0.02266645}
# I0621 05:58:55.437178 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.24528205,
#  'Loss/localization_loss': 0.1136791,
#  'Loss/regularization_loss': 0.26196855,
#  'Loss/total_loss': 0.6209297,
#  'learning_rate': 0.02266645}
# INFO:tensorflow:Step 800 per-step time 0.557s
# I0621 05:59:51.112816 140686958434176 model_lib_v2.py:707] Step 800 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.30794615,
#  'Loss/localization_loss': 0.06392246,
#  'Loss/regularization_loss': 0.26168087,
#  'Loss/total_loss': 0.63354945,
#  'learning_rate': 0.023999799}
# I0621 05:59:51.113169 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.30794615,
#  'Loss/localization_loss': 0.06392246,
#  'Loss/regularization_loss': 0.26168087,
#  'Loss/total_loss': 0.63354945,
#  'learning_rate': 0.023999799}
# INFO:tensorflow:Step 900 per-step time 0.557s
# I0621 06:00:46.779191 140686958434176 model_lib_v2.py:707] Step 900 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.26021293,
#  'Loss/localization_loss': 0.04833758,
#  'Loss/regularization_loss': 0.25972015,
#  'Loss/total_loss': 0.5682707,
#  'learning_rate': 0.025333151}
# I0621 06:00:46.779544 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.26021293,
#  'Loss/localization_loss': 0.04833758,
#  'Loss/regularization_loss': 0.25972015,
#  'Loss/total_loss': 0.5682707,
#  'learning_rate': 0.025333151}
# INFO:tensorflow:Step 1000 per-step time 0.558s
# I0621 06:01:42.556343 140686958434176 model_lib_v2.py:707] Step 1000 per-step time 0.558s
# INFO:tensorflow:{'Loss/classification_loss': 0.24772143,
#  'Loss/localization_loss': 0.039662104,
#  'Loss/regularization_loss': 0.2574199,
#  'Loss/total_loss': 0.54480344,
#  'learning_rate': 0.0266665}
# I0621 06:01:42.556639 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.24772143,
#  'Loss/localization_loss': 0.039662104,
#  'Loss/regularization_loss': 0.2574199,
#  'Loss/total_loss': 0.54480344,
#  'learning_rate': 0.0266665}
# INFO:tensorflow:Step 1100 per-step time 0.571s
# I0621 06:02:39.654093 140686958434176 model_lib_v2.py:707] Step 1100 per-step time 0.571s
# INFO:tensorflow:{'Loss/classification_loss': 0.202014,
#  'Loss/localization_loss': 0.038187798,
#  'Loss/regularization_loss': 0.25431725,
#  'Loss/total_loss': 0.49451905,
#  'learning_rate': 0.02799985}
# I0621 06:02:39.654509 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.202014,
#  'Loss/localization_loss': 0.038187798,
#  'Loss/regularization_loss': 0.25431725,
#  'Loss/total_loss': 0.49451905,
#  'learning_rate': 0.02799985}
# INFO:tensorflow:Step 1200 per-step time 0.556s
# I0621 06:03:35.242845 140686958434176 model_lib_v2.py:707] Step 1200 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.24705863,
#  'Loss/localization_loss': 0.09449004,
#  'Loss/regularization_loss': 0.25135198,
#  'Loss/total_loss': 0.59290063,
#  'learning_rate': 0.0293332}
# I0621 06:03:35.243176 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.24705863,
#  'Loss/localization_loss': 0.09449004,
#  'Loss/regularization_loss': 0.25135198,
#  'Loss/total_loss': 0.59290063,
#  'learning_rate': 0.0293332}
# INFO:tensorflow:Step 1300 per-step time 0.557s
# I0621 06:04:30.990180 140686958434176 model_lib_v2.py:707] Step 1300 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.211621,
#  'Loss/localization_loss': 0.039930254,
#  'Loss/regularization_loss': 0.24984442,
#  'Loss/total_loss': 0.5013957,
#  'learning_rate': 0.03066655}
# I0621 06:04:30.990535 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.211621,
#  'Loss/localization_loss': 0.039930254,
#  'Loss/regularization_loss': 0.24984442,
#  'Loss/total_loss': 0.5013957,
#  'learning_rate': 0.03066655}
# INFO:tensorflow:Step 1400 per-step time 0.557s
# I0621 06:05:26.718208 140686958434176 model_lib_v2.py:707] Step 1400 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.23302674,
#  'Loss/localization_loss': 0.05878868,
#  'Loss/regularization_loss': 0.24929002,
#  'Loss/total_loss': 0.54110545,
#  'learning_rate': 0.0319999}
# I0621 06:05:26.718523 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.23302674,
#  'Loss/localization_loss': 0.05878868,
#  'Loss/regularization_loss': 0.24929002,
#  'Loss/total_loss': 0.54110545,
#  'learning_rate': 0.0319999}
# INFO:tensorflow:Step 1500 per-step time 0.557s
# I0621 06:06:22.411928 140686958434176 model_lib_v2.py:707] Step 1500 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.25991654,
#  'Loss/localization_loss': 0.05493567,
#  'Loss/regularization_loss': 0.24752031,
#  'Loss/total_loss': 0.5623725,
#  'learning_rate': 0.03333325}
# I0621 06:06:22.412298 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.25991654,
#  'Loss/localization_loss': 0.05493567,
#  'Loss/regularization_loss': 0.24752031,
#  'Loss/total_loss': 0.5623725,
#  'learning_rate': 0.03333325}
# INFO:tensorflow:Step 1600 per-step time 0.556s
# I0621 06:07:17.982827 140686958434176 model_lib_v2.py:707] Step 1600 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.1954593,
#  'Loss/localization_loss': 0.038131602,
#  'Loss/regularization_loss': 0.24628092,
#  'Loss/total_loss': 0.4798718,
#  'learning_rate': 0.034666598}
# I0621 06:07:17.983167 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.1954593,
#  'Loss/localization_loss': 0.038131602,
#  'Loss/regularization_loss': 0.24628092,
#  'Loss/total_loss': 0.4798718,
#  'learning_rate': 0.034666598}
# INFO:tensorflow:Step 1700 per-step time 0.557s
# I0621 06:08:13.680155 140686958434176 model_lib_v2.py:707] Step 1700 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.29707393,
#  'Loss/localization_loss': 0.065362684,
#  'Loss/regularization_loss': 0.24353683,
#  'Loss/total_loss': 0.6059735,
#  'learning_rate': 0.03599995}
# I0621 06:08:13.680465 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.29707393,
#  'Loss/localization_loss': 0.065362684,
#  'Loss/regularization_loss': 0.24353683,
#  'Loss/total_loss': 0.6059735,
#  'learning_rate': 0.03599995}
# INFO:tensorflow:Step 1800 per-step time 0.557s
# I0621 06:09:09.396504 140686958434176 model_lib_v2.py:707] Step 1800 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.21920241,
#  'Loss/localization_loss': 0.067847565,
#  'Loss/regularization_loss': 0.24239385,
#  'Loss/total_loss': 0.52944386,
#  'learning_rate': 0.037333302}
# I0621 06:09:09.396856 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.21920241,
#  'Loss/localization_loss': 0.067847565,
#  'Loss/regularization_loss': 0.24239385,
#  'Loss/total_loss': 0.52944386,
#  'learning_rate': 0.037333302}
# INFO:tensorflow:Step 1900 per-step time 0.557s
# I0621 06:10:05.134845 140686958434176 model_lib_v2.py:707] Step 1900 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.18544334,
#  'Loss/localization_loss': 0.039992165,
#  'Loss/regularization_loss': 0.24178775,
#  'Loss/total_loss': 0.46722326,
#  'learning_rate': 0.03866665}
# I0621 06:10:05.135168 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.18544334,
#  'Loss/localization_loss': 0.039992165,
#  'Loss/regularization_loss': 0.24178775,
#  'Loss/total_loss': 0.46722326,
#  'learning_rate': 0.03866665}
# INFO:tensorflow:Step 2000 per-step time 0.557s
# I0621 06:11:00.829714 140686958434176 model_lib_v2.py:707] Step 2000 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.23996787,
#  'Loss/localization_loss': 0.06666593,
#  'Loss/regularization_loss': 0.23994595,
#  'Loss/total_loss': 0.5465797,
#  'learning_rate': 0.04}
# I0621 06:11:00.830092 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.23996787,
#  'Loss/localization_loss': 0.06666593,
#  'Loss/regularization_loss': 0.23994595,
#  'Loss/total_loss': 0.5465797,
#  'learning_rate': 0.04}
# INFO:tensorflow:Step 2100 per-step time 0.579s
# I0621 06:11:58.709205 140686958434176 model_lib_v2.py:707] Step 2100 per-step time 0.579s
# INFO:tensorflow:{'Loss/classification_loss': 0.1559264,
#  'Loss/localization_loss': 0.030722456,
#  'Loss/regularization_loss': 0.23724766,
#  'Loss/total_loss': 0.42389652,
#  'learning_rate': 0.039998136}
# I0621 06:11:58.709510 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.1559264,
#  'Loss/localization_loss': 0.030722456,
#  'Loss/regularization_loss': 0.23724766,
#  'Loss/total_loss': 0.42389652,
#  'learning_rate': 0.039998136}
# INFO:tensorflow:Step 2200 per-step time 0.556s
# I0621 06:12:54.328419 140686958434176 model_lib_v2.py:707] Step 2200 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.18054275,
#  'Loss/localization_loss': 0.049601085,
#  'Loss/regularization_loss': 0.2336286,
#  'Loss/total_loss': 0.46377245,
#  'learning_rate': 0.039992537}
# I0621 06:12:54.328768 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.18054275,
#  'Loss/localization_loss': 0.049601085,
#  'Loss/regularization_loss': 0.2336286,
#  'Loss/total_loss': 0.46377245,
#  'learning_rate': 0.039992537}
# INFO:tensorflow:Step 2300 per-step time 0.556s
# I0621 06:13:49.939595 140686958434176 model_lib_v2.py:707] Step 2300 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.1840008,
#  'Loss/localization_loss': 0.02808219,
#  'Loss/regularization_loss': 0.23178005,
#  'Loss/total_loss': 0.44386303,
#  'learning_rate': 0.03998321}
# I0621 06:13:49.939899 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.1840008,
#  'Loss/localization_loss': 0.02808219,
#  'Loss/regularization_loss': 0.23178005,
#  'Loss/total_loss': 0.44386303,
#  'learning_rate': 0.03998321}
# INFO:tensorflow:Step 2400 per-step time 0.557s
# I0621 06:14:45.602162 140686958434176 model_lib_v2.py:707] Step 2400 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.24823196,
#  'Loss/localization_loss': 0.051455855,
#  'Loss/regularization_loss': 0.22982806,
#  'Loss/total_loss': 0.52951586,
#  'learning_rate': 0.039970152}
# I0621 06:14:45.602517 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.24823196,
#  'Loss/localization_loss': 0.051455855,
#  'Loss/regularization_loss': 0.22982806,
#  'Loss/total_loss': 0.52951586,
#  'learning_rate': 0.039970152}
# INFO:tensorflow:Step 2500 per-step time 0.556s
# I0621 06:15:41.186646 140686958434176 model_lib_v2.py:707] Step 2500 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.18226601,
#  'Loss/localization_loss': 0.02745213,
#  'Loss/regularization_loss': 0.22730671,
#  'Loss/total_loss': 0.43702483,
#  'learning_rate': 0.039953373}
# I0621 06:15:41.186951 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.18226601,
#  'Loss/localization_loss': 0.02745213,
#  'Loss/regularization_loss': 0.22730671,
#  'Loss/total_loss': 0.43702483,
#  'learning_rate': 0.039953373}
# INFO:tensorflow:Step 2600 per-step time 0.557s
# I0621 06:16:36.895175 140686958434176 model_lib_v2.py:707] Step 2600 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.15792345,
#  'Loss/localization_loss': 0.057778526,
#  'Loss/regularization_loss': 0.22715476,
#  'Loss/total_loss': 0.44285673,
#  'learning_rate': 0.03993287}
# I0621 06:16:36.895532 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.15792345,
#  'Loss/localization_loss': 0.057778526,
#  'Loss/regularization_loss': 0.22715476,
#  'Loss/total_loss': 0.44285673,
#  'learning_rate': 0.03993287}
# INFO:tensorflow:Step 2700 per-step time 0.557s
# I0621 06:17:32.570509 140686958434176 model_lib_v2.py:707] Step 2700 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.17940988,
#  'Loss/localization_loss': 0.0549504,
#  'Loss/regularization_loss': 0.22594643,
#  'Loss/total_loss': 0.4603067,
#  'learning_rate': 0.039908648}
# I0621 06:17:32.570815 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.17940988,
#  'Loss/localization_loss': 0.0549504,
#  'Loss/regularization_loss': 0.22594643,
#  'Loss/total_loss': 0.4603067,
#  'learning_rate': 0.039908648}
# INFO:tensorflow:Step 2800 per-step time 0.557s
# I0621 06:18:28.242444 140686958434176 model_lib_v2.py:707] Step 2800 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.20985621,
#  'Loss/localization_loss': 0.084983,
#  'Loss/regularization_loss': 0.22858234,
#  'Loss/total_loss': 0.5234215,
#  'learning_rate': 0.039880715}
# I0621 06:18:28.242779 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.20985621,
#  'Loss/localization_loss': 0.084983,
#  'Loss/regularization_loss': 0.22858234,
#  'Loss/total_loss': 0.5234215,
#  'learning_rate': 0.039880715}
# INFO:tensorflow:Step 2900 per-step time 0.556s
# I0621 06:19:23.828368 140686958434176 model_lib_v2.py:707] Step 2900 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.3244276,
#  'Loss/localization_loss': 0.04442775,
#  'Loss/regularization_loss': 0.23241684,
#  'Loss/total_loss': 0.6012722,
#  'learning_rate': 0.039849065}
# I0621 06:19:23.828677 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.3244276,
#  'Loss/localization_loss': 0.04442775,
#  'Loss/regularization_loss': 0.23241684,
#  'Loss/total_loss': 0.6012722,
#  'learning_rate': 0.039849065}
# INFO:tensorflow:Step 3000 per-step time 0.557s
# I0621 06:20:19.482430 140686958434176 model_lib_v2.py:707] Step 3000 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.14718805,
#  'Loss/localization_loss': 0.03649324,
#  'Loss/regularization_loss': 0.23705047,
#  'Loss/total_loss': 0.42073178,
#  'learning_rate': 0.03981372}
# I0621 06:20:19.482761 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.14718805,
#  'Loss/localization_loss': 0.03649324,
#  'Loss/regularization_loss': 0.23705047,
#  'Loss/total_loss': 0.42073178,
#  'learning_rate': 0.03981372}
# INFO:tensorflow:Step 3100 per-step time 0.570s
# I0621 06:21:16.524718 140686958434176 model_lib_v2.py:707] Step 3100 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.1256361,
#  'Loss/localization_loss': 0.034322858,
#  'Loss/regularization_loss': 0.23609667,
#  'Loss/total_loss': 0.39605564,
#  'learning_rate': 0.03977467}
# I0621 06:21:16.525063 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.1256361,
#  'Loss/localization_loss': 0.034322858,
#  'Loss/regularization_loss': 0.23609667,
#  'Loss/total_loss': 0.39605564,
#  'learning_rate': 0.03977467}
# INFO:tensorflow:Step 3200 per-step time 0.557s
# I0621 06:22:12.224791 140686958434176 model_lib_v2.py:707] Step 3200 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.115000434,
#  'Loss/localization_loss': 0.02231315,
#  'Loss/regularization_loss': 0.23498109,
#  'Loss/total_loss': 0.37229466,
#  'learning_rate': 0.03973194}
# I0621 06:22:12.225115 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.115000434,
#  'Loss/localization_loss': 0.02231315,
#  'Loss/regularization_loss': 0.23498109,
#  'Loss/total_loss': 0.37229466,
#  'learning_rate': 0.03973194}
# INFO:tensorflow:Step 3300 per-step time 0.557s
# I0621 06:23:07.896581 140686958434176 model_lib_v2.py:707] Step 3300 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.14189662,
#  'Loss/localization_loss': 0.07601986,
#  'Loss/regularization_loss': 0.23164536,
#  'Loss/total_loss': 0.44956183,
#  'learning_rate': 0.03968552}
# I0621 06:23:07.896926 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.14189662,
#  'Loss/localization_loss': 0.07601986,
#  'Loss/regularization_loss': 0.23164536,
#  'Loss/total_loss': 0.44956183,
#  'learning_rate': 0.03968552}
# INFO:tensorflow:Step 3400 per-step time 0.557s
# I0621 06:24:03.553406 140686958434176 model_lib_v2.py:707] Step 3400 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.12553887,
#  'Loss/localization_loss': 0.032524265,
#  'Loss/regularization_loss': 0.22748476,
#  'Loss/total_loss': 0.3855479,
#  'learning_rate': 0.039635435}
# I0621 06:24:03.553705 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.12553887,
#  'Loss/localization_loss': 0.032524265,
#  'Loss/regularization_loss': 0.22748476,
#  'Loss/total_loss': 0.3855479,
#  'learning_rate': 0.039635435}
# INFO:tensorflow:Step 3500 per-step time 0.557s
# I0621 06:24:59.223690 140686958434176 model_lib_v2.py:707] Step 3500 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.15175158,
#  'Loss/localization_loss': 0.05657092,
#  'Loss/regularization_loss': 0.22386076,
#  'Loss/total_loss': 0.43218327,
#  'learning_rate': 0.03958168}
# I0621 06:24:59.224084 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.15175158,
#  'Loss/localization_loss': 0.05657092,
#  'Loss/regularization_loss': 0.22386076,
#  'Loss/total_loss': 0.43218327,
#  'learning_rate': 0.03958168}
# INFO:tensorflow:Step 3600 per-step time 0.557s
# I0621 06:25:54.895145 140686958434176 model_lib_v2.py:707] Step 3600 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.11076426,
#  'Loss/localization_loss': 0.024604164,
#  'Loss/regularization_loss': 0.22039258,
#  'Loss/total_loss': 0.355761,
#  'learning_rate': 0.039524276}
# I0621 06:25:54.895455 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.11076426,
#  'Loss/localization_loss': 0.024604164,
#  'Loss/regularization_loss': 0.22039258,
#  'Loss/total_loss': 0.355761,
#  'learning_rate': 0.039524276}
# INFO:tensorflow:Step 3700 per-step time 0.557s
# I0621 06:26:50.626145 140686958434176 model_lib_v2.py:707] Step 3700 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.09876213,
#  'Loss/localization_loss': 0.0280814,
#  'Loss/regularization_loss': 0.21750042,
#  'Loss/total_loss': 0.34434396,
#  'learning_rate': 0.03946323}
# I0621 06:26:50.626501 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.09876213,
#  'Loss/localization_loss': 0.0280814,
#  'Loss/regularization_loss': 0.21750042,
#  'Loss/total_loss': 0.34434396,
#  'learning_rate': 0.03946323}
# INFO:tensorflow:Step 3800 per-step time 0.557s
# I0621 06:27:46.346153 140686958434176 model_lib_v2.py:707] Step 3800 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.11861511,
#  'Loss/localization_loss': 0.026854942,
#  'Loss/regularization_loss': 0.21464041,
#  'Loss/total_loss': 0.36011046,
#  'learning_rate': 0.039398547}
# I0621 06:27:46.346456 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.11861511,
#  'Loss/localization_loss': 0.026854942,
#  'Loss/regularization_loss': 0.21464041,
#  'Loss/total_loss': 0.36011046,
#  'learning_rate': 0.039398547}
# INFO:tensorflow:Step 3900 per-step time 0.558s
# I0621 06:28:42.182880 140686958434176 model_lib_v2.py:707] Step 3900 per-step time 0.558s
# INFO:tensorflow:{'Loss/classification_loss': 0.16167329,
#  'Loss/localization_loss': 0.013987384,
#  'Loss/regularization_loss': 0.21293974,
#  'Loss/total_loss': 0.3886004,
#  'learning_rate': 0.039330248}
# I0621 06:28:42.183284 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.16167329,
#  'Loss/localization_loss': 0.013987384,
#  'Loss/regularization_loss': 0.21293974,
#  'Loss/total_loss': 0.3886004,
#  'learning_rate': 0.039330248}
# INFO:tensorflow:Step 4000 per-step time 0.556s
# I0621 06:29:37.819085 140686958434176 model_lib_v2.py:707] Step 4000 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.16368246,
#  'Loss/localization_loss': 0.018226031,
#  'Loss/regularization_loss': 0.21038125,
#  'Loss/total_loss': 0.39228976,
#  'learning_rate': 0.039258346}
# I0621 06:29:37.819394 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.16368246,
#  'Loss/localization_loss': 0.018226031,
#  'Loss/regularization_loss': 0.21038125,
#  'Loss/total_loss': 0.39228976,
#  'learning_rate': 0.039258346}
# INFO:tensorflow:Step 4100 per-step time 0.576s
# I0621 06:30:35.421015 140686958434176 model_lib_v2.py:707] Step 4100 per-step time 0.576s
# INFO:tensorflow:{'Loss/classification_loss': 0.12362983,
#  'Loss/localization_loss': 0.016555056,
#  'Loss/regularization_loss': 0.2083323,
#  'Loss/total_loss': 0.34851718,
#  'learning_rate': 0.03918285}
# I0621 06:30:35.421391 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.12362983,
#  'Loss/localization_loss': 0.016555056,
#  'Loss/regularization_loss': 0.2083323,
#  'Loss/total_loss': 0.34851718,
#  'learning_rate': 0.03918285}
# INFO:tensorflow:Step 4200 per-step time 0.557s
# I0621 06:31:31.151349 140686958434176 model_lib_v2.py:707] Step 4200 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.122277044,
#  'Loss/localization_loss': 0.020037415,
#  'Loss/regularization_loss': 0.20585957,
#  'Loss/total_loss': 0.34817404,
#  'learning_rate': 0.03910377}
# I0621 06:31:31.151642 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.122277044,
#  'Loss/localization_loss': 0.020037415,
#  'Loss/regularization_loss': 0.20585957,
#  'Loss/total_loss': 0.34817404,
#  'learning_rate': 0.03910377}
# INFO:tensorflow:Step 4300 per-step time 0.558s
# I0621 06:32:26.929800 140686958434176 model_lib_v2.py:707] Step 4300 per-step time 0.558s
# INFO:tensorflow:{'Loss/classification_loss': 0.107177444,
#  'Loss/localization_loss': 0.014391282,
#  'Loss/regularization_loss': 0.20415746,
#  'Loss/total_loss': 0.32572618,
#  'learning_rate': 0.039021127}
# I0621 06:32:26.930146 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.107177444,
#  'Loss/localization_loss': 0.014391282,
#  'Loss/regularization_loss': 0.20415746,
#  'Loss/total_loss': 0.32572618,
#  'learning_rate': 0.039021127}
# INFO:tensorflow:Step 4400 per-step time 0.556s
# I0621 06:33:22.557382 140686958434176 model_lib_v2.py:707] Step 4400 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.13444889,
#  'Loss/localization_loss': 0.022015298,
#  'Loss/regularization_loss': 0.20260751,
#  'Loss/total_loss': 0.3590717,
#  'learning_rate': 0.03893494}
# I0621 06:33:22.557710 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.13444889,
#  'Loss/localization_loss': 0.022015298,
#  'Loss/regularization_loss': 0.20260751,
#  'Loss/total_loss': 0.3590717,
#  'learning_rate': 0.03893494}
# INFO:tensorflow:Step 4500 per-step time 0.557s
# I0621 06:34:18.212413 140686958434176 model_lib_v2.py:707] Step 4500 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.11965073,
#  'Loss/localization_loss': 0.022745514,
#  'Loss/regularization_loss': 0.19934803,
#  'Loss/total_loss': 0.34174427,
#  'learning_rate': 0.03884522}
# I0621 06:34:18.212728 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.11965073,
#  'Loss/localization_loss': 0.022745514,
#  'Loss/regularization_loss': 0.19934803,
#  'Loss/total_loss': 0.34174427,
#  'learning_rate': 0.03884522}
# INFO:tensorflow:Step 4600 per-step time 0.557s
# I0621 06:35:13.873605 140686958434176 model_lib_v2.py:707] Step 4600 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.1658081,
#  'Loss/localization_loss': 0.024956202,
#  'Loss/regularization_loss': 0.19805749,
#  'Loss/total_loss': 0.38882178,
#  'learning_rate': 0.03875198}
# I0621 06:35:13.873947 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.1658081,
#  'Loss/localization_loss': 0.024956202,
#  'Loss/regularization_loss': 0.19805749,
#  'Loss/total_loss': 0.38882178,
#  'learning_rate': 0.03875198}
# INFO:tensorflow:Step 4700 per-step time 0.558s
# I0621 06:36:09.640293 140686958434176 model_lib_v2.py:707] Step 4700 per-step time 0.558s
# INFO:tensorflow:{'Loss/classification_loss': 0.12990513,
#  'Loss/localization_loss': 0.022851286,
#  'Loss/regularization_loss': 0.19789374,
#  'Loss/total_loss': 0.35065016,
#  'learning_rate': 0.038655244}
# I0621 06:36:09.640609 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.12990513,
#  'Loss/localization_loss': 0.022851286,
#  'Loss/regularization_loss': 0.19789374,
#  'Loss/total_loss': 0.35065016,
#  'learning_rate': 0.038655244}
# INFO:tensorflow:Step 4800 per-step time 0.556s
# I0621 06:37:05.270047 140686958434176 model_lib_v2.py:707] Step 4800 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.094973736,
#  'Loss/localization_loss': 0.013645488,
#  'Loss/regularization_loss': 0.19525997,
#  'Loss/total_loss': 0.3038792,
#  'learning_rate': 0.038555026}
# I0621 06:37:05.270408 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.094973736,
#  'Loss/localization_loss': 0.013645488,
#  'Loss/regularization_loss': 0.19525997,
#  'Loss/total_loss': 0.3038792,
#  'learning_rate': 0.038555026}
# INFO:tensorflow:Step 4900 per-step time 0.556s
# I0621 06:38:00.877394 140686958434176 model_lib_v2.py:707] Step 4900 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.16222209,
#  'Loss/localization_loss': 0.04262992,
#  'Loss/regularization_loss': 0.19437107,
#  'Loss/total_loss': 0.3992231,
#  'learning_rate': 0.038451348}
# I0621 06:38:00.877690 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.16222209,
#  'Loss/localization_loss': 0.04262992,
#  'Loss/regularization_loss': 0.19437107,
#  'Loss/total_loss': 0.3992231,
#  'learning_rate': 0.038451348}
# INFO:tensorflow:Step 5000 per-step time 0.557s
# I0621 06:38:56.543326 140686958434176 model_lib_v2.py:707] Step 5000 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.10725451,
#  'Loss/localization_loss': 0.033189107,
#  'Loss/regularization_loss': 0.19280085,
#  'Loss/total_loss': 0.33324447,
#  'learning_rate': 0.038344227}
# I0621 06:38:56.543715 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.10725451,
#  'Loss/localization_loss': 0.033189107,
#  'Loss/regularization_loss': 0.19280085,
#  'Loss/total_loss': 0.33324447,
#  'learning_rate': 0.038344227}
# INFO:tensorflow:Step 5100 per-step time 0.571s
# I0621 06:39:53.651331 140686958434176 model_lib_v2.py:707] Step 5100 per-step time 0.571s
# INFO:tensorflow:{'Loss/classification_loss': 0.10781128,
#  'Loss/localization_loss': 0.020252205,
#  'Loss/regularization_loss': 0.18963884,
#  'Loss/total_loss': 0.31770232,
#  'learning_rate': 0.03823368}
# I0621 06:39:53.651651 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.10781128,
#  'Loss/localization_loss': 0.020252205,
#  'Loss/regularization_loss': 0.18963884,
#  'Loss/total_loss': 0.31770232,
#  'learning_rate': 0.03823368}
# INFO:tensorflow:Step 5200 per-step time 0.557s
# I0621 06:40:49.304445 140686958434176 model_lib_v2.py:707] Step 5200 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.15503135,
#  'Loss/localization_loss': 0.018932361,
#  'Loss/regularization_loss': 0.18641682,
#  'Loss/total_loss': 0.36038053,
#  'learning_rate': 0.038119733}
# I0621 06:40:49.304797 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.15503135,
#  'Loss/localization_loss': 0.018932361,
#  'Loss/regularization_loss': 0.18641682,
#  'Loss/total_loss': 0.36038053,
#  'learning_rate': 0.038119733}
# INFO:tensorflow:Step 5300 per-step time 0.557s
# I0621 06:41:45.006353 140686958434176 model_lib_v2.py:707] Step 5300 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.099831834,
#  'Loss/localization_loss': 0.021742182,
#  'Loss/regularization_loss': 0.18623513,
#  'Loss/total_loss': 0.30780914,
#  'learning_rate': 0.03800241}
# I0621 06:41:45.006676 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.099831834,
#  'Loss/localization_loss': 0.021742182,
#  'Loss/regularization_loss': 0.18623513,
#  'Loss/total_loss': 0.30780914,
#  'learning_rate': 0.03800241}
# INFO:tensorflow:Step 5400 per-step time 0.557s
# I0621 06:42:40.688529 140686958434176 model_lib_v2.py:707] Step 5400 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.095449835,
#  'Loss/localization_loss': 0.01880011,
#  'Loss/regularization_loss': 0.18465672,
#  'Loss/total_loss': 0.29890668,
#  'learning_rate': 0.037881725}
# I0621 06:42:40.688884 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.095449835,
#  'Loss/localization_loss': 0.01880011,
#  'Loss/regularization_loss': 0.18465672,
#  'Loss/total_loss': 0.29890668,
#  'learning_rate': 0.037881725}
# INFO:tensorflow:Step 5500 per-step time 0.556s
# I0621 06:43:36.327750 140686958434176 model_lib_v2.py:707] Step 5500 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.079118885,
#  'Loss/localization_loss': 0.015605663,
#  'Loss/regularization_loss': 0.18287168,
#  'Loss/total_loss': 0.27759624,
#  'learning_rate': 0.037757702}
# I0621 06:43:36.328058 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.079118885,
#  'Loss/localization_loss': 0.015605663,
#  'Loss/regularization_loss': 0.18287168,
#  'Loss/total_loss': 0.27759624,
#  'learning_rate': 0.037757702}
# INFO:tensorflow:Step 5600 per-step time 0.556s
# I0621 06:44:31.968310 140686958434176 model_lib_v2.py:707] Step 5600 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.22281882,
#  'Loss/localization_loss': 0.016132832,
#  'Loss/regularization_loss': 0.18100719,
#  'Loss/total_loss': 0.41995883,
#  'learning_rate': 0.03763037}
# I0621 06:44:31.968646 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.22281882,
#  'Loss/localization_loss': 0.016132832,
#  'Loss/regularization_loss': 0.18100719,
#  'Loss/total_loss': 0.41995883,
#  'learning_rate': 0.03763037}
# INFO:tensorflow:Step 5700 per-step time 0.557s
# I0621 06:45:27.711906 140686958434176 model_lib_v2.py:707] Step 5700 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.08802979,
#  'Loss/localization_loss': 0.014070529,
#  'Loss/regularization_loss': 0.18177527,
#  'Loss/total_loss': 0.28387558,
#  'learning_rate': 0.03749975}
# I0621 06:45:27.712229 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.08802979,
#  'Loss/localization_loss': 0.014070529,
#  'Loss/regularization_loss': 0.18177527,
#  'Loss/total_loss': 0.28387558,
#  'learning_rate': 0.03749975}
# INFO:tensorflow:Step 5800 per-step time 0.557s
# I0621 06:46:23.352879 140686958434176 model_lib_v2.py:707] Step 5800 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.08589705,
#  'Loss/localization_loss': 0.012096876,
#  'Loss/regularization_loss': 0.17953509,
#  'Loss/total_loss': 0.277529,
#  'learning_rate': 0.037365858}
# I0621 06:46:23.353221 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.08589705,
#  'Loss/localization_loss': 0.012096876,
#  'Loss/regularization_loss': 0.17953509,
#  'Loss/total_loss': 0.277529,
#  'learning_rate': 0.037365858}
# INFO:tensorflow:Step 5900 per-step time 0.557s
# I0621 06:47:19.065896 140686958434176 model_lib_v2.py:707] Step 5900 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.103361756,
#  'Loss/localization_loss': 0.02026145,
#  'Loss/regularization_loss': 0.17731225,
#  'Loss/total_loss': 0.30093545,
#  'learning_rate': 0.03722873}
# I0621 06:47:19.066220 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.103361756,
#  'Loss/localization_loss': 0.02026145,
#  'Loss/regularization_loss': 0.17731225,
#  'Loss/total_loss': 0.30093545,
#  'learning_rate': 0.03722873}
# INFO:tensorflow:Step 6000 per-step time 0.557s
# I0621 06:48:14.741400 140686958434176 model_lib_v2.py:707] Step 6000 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.10972821,
#  'Loss/localization_loss': 0.021511525,
#  'Loss/regularization_loss': 0.17507437,
#  'Loss/total_loss': 0.3063141,
#  'learning_rate': 0.037088387}
# I0621 06:48:14.741720 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.10972821,
#  'Loss/localization_loss': 0.021511525,
#  'Loss/regularization_loss': 0.17507437,
#  'Loss/total_loss': 0.3063141,
#  'learning_rate': 0.037088387}
# INFO:tensorflow:Step 6100 per-step time 0.572s
# I0621 06:49:11.949730 140686958434176 model_lib_v2.py:707] Step 6100 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.07173889,
#  'Loss/localization_loss': 0.012421936,
#  'Loss/regularization_loss': 0.17232125,
#  'Loss/total_loss': 0.25648206,
#  'learning_rate': 0.036944855}
# I0621 06:49:11.950092 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.07173889,
#  'Loss/localization_loss': 0.012421936,
#  'Loss/regularization_loss': 0.17232125,
#  'Loss/total_loss': 0.25648206,
#  'learning_rate': 0.036944855}
# INFO:tensorflow:Step 6200 per-step time 0.556s
# I0621 06:50:07.559918 140686958434176 model_lib_v2.py:707] Step 6200 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.15024552,
#  'Loss/localization_loss': 0.013460996,
#  'Loss/regularization_loss': 0.1701978,
#  'Loss/total_loss': 0.33390433,
#  'learning_rate': 0.036798168}
# I0621 06:50:07.560240 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.15024552,
#  'Loss/localization_loss': 0.013460996,
#  'Loss/regularization_loss': 0.1701978,
#  'Loss/total_loss': 0.33390433,
#  'learning_rate': 0.036798168}
# INFO:tensorflow:Step 6300 per-step time 0.557s
# I0621 06:51:03.242712 140686958434176 model_lib_v2.py:707] Step 6300 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.1178827,
#  'Loss/localization_loss': 0.013185843,
#  'Loss/regularization_loss': 0.16777264,
#  'Loss/total_loss': 0.29884118,
#  'learning_rate': 0.03664834}
# I0621 06:51:03.243083 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.1178827,
#  'Loss/localization_loss': 0.013185843,
#  'Loss/regularization_loss': 0.16777264,
#  'Loss/total_loss': 0.29884118,
#  'learning_rate': 0.03664834}
# INFO:tensorflow:Step 6400 per-step time 0.557s
# I0621 06:51:58.908000 140686958434176 model_lib_v2.py:707] Step 6400 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.074076235,
#  'Loss/localization_loss': 0.012475594,
#  'Loss/regularization_loss': 0.16615632,
#  'Loss/total_loss': 0.25270814,
#  'learning_rate': 0.03649541}
# I0621 06:51:58.908324 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.074076235,
#  'Loss/localization_loss': 0.012475594,
#  'Loss/regularization_loss': 0.16615632,
#  'Loss/total_loss': 0.25270814,
#  'learning_rate': 0.03649541}
# INFO:tensorflow:Step 6500 per-step time 0.556s
# I0621 06:52:54.527042 140686958434176 model_lib_v2.py:707] Step 6500 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.13779335,
#  'Loss/localization_loss': 0.02342939,
#  'Loss/regularization_loss': 0.16510986,
#  'Loss/total_loss': 0.3263326,
#  'learning_rate': 0.0363394}
# I0621 06:52:54.527392 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.13779335,
#  'Loss/localization_loss': 0.02342939,
#  'Loss/regularization_loss': 0.16510986,
#  'Loss/total_loss': 0.3263326,
#  'learning_rate': 0.0363394}
# INFO:tensorflow:Step 6600 per-step time 0.557s
# I0621 06:53:50.221141 140686958434176 model_lib_v2.py:707] Step 6600 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.08904875,
#  'Loss/localization_loss': 0.015055377,
#  'Loss/regularization_loss': 0.16509145,
#  'Loss/total_loss': 0.2691956,
#  'learning_rate': 0.03618034}
# ...
#  'learning_rate': 0.033849433}
# I0621 07:05:55.668436 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.07580145,
#  'Loss/localization_loss': 0.017113721,
#  'Loss/regularization_loss': 0.1537606,
#  'Loss/total_loss': 0.24667576,
#  'learning_rate': 0.033849433}
# INFO:tensorflow:Step 8000 per-step time 0.557s
# I0621 07:06:51.335872 140686958434176 model_lib_v2.py:707] Step 8000 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.05193934,
#  'Loss/localization_loss': 0.017772067,
#  'Loss/regularization_loss': 0.15162608,
#  'Loss/total_loss': 0.22133748,
#  'learning_rate': 0.03365106}
# I0621 07:06:51.336236 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.05193934,
#  'Loss/localization_loss': 0.017772067,
#  'Loss/regularization_loss': 0.15162608,
#  'Loss/total_loss': 0.22133748,
#  'learning_rate': 0.03365106}
# INFO:tensorflow:Step 8100 per-step time 0.570s
# I0621 07:07:48.365111 140686958434176 model_lib_v2.py:707] Step 8100 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.077863604,
#  'Loss/localization_loss': 0.011734232,
#  'Loss/regularization_loss': 0.15338115,
#  'Loss/total_loss': 0.24297899,
#  'learning_rate': 0.033450145}
# I0621 07:07:48.365418 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.077863604,
#  'Loss/localization_loss': 0.011734232,
#  'Loss/regularization_loss': 0.15338115,
#  'Loss/total_loss': 0.24297899,
#  'learning_rate': 0.033450145}
# INFO:tensorflow:Step 8200 per-step time 0.556s
# I0621 07:08:43.937732 140686958434176 model_lib_v2.py:707] Step 8200 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.08419864,
#  'Loss/localization_loss': 0.015932985,
#  'Loss/regularization_loss': 0.15144515,
#  'Loss/total_loss': 0.25157678,
#  'learning_rate': 0.03324672}
# I0621 07:08:43.938081 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.08419864,
#  'Loss/localization_loss': 0.015932985,
#  'Loss/regularization_loss': 0.15144515,
#  'Loss/total_loss': 0.25157678,
#  'learning_rate': 0.03324672}
# INFO:tensorflow:Step 8300 per-step time 0.555s
# I0621 07:09:39.467822 140686958434176 model_lib_v2.py:707] Step 8300 per-step time 0.555s
# INFO:tensorflow:{'Loss/classification_loss': 0.061388336,
#  'Loss/localization_loss': 0.011347493,
#  'Loss/regularization_loss': 0.14971486,
#  'Loss/total_loss': 0.22245069,
#  'learning_rate': 0.033040818}
# I0621 07:09:39.468185 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.061388336,
#  'Loss/localization_loss': 0.011347493,
#  'Loss/regularization_loss': 0.14971486,
#  'Loss/total_loss': 0.22245069,
#  'learning_rate': 0.033040818}
# INFO:tensorflow:Step 8400 per-step time 0.557s
# I0621 07:10:35.212788 140686958434176 model_lib_v2.py:707] Step 8400 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.082555085,
#  'Loss/localization_loss': 0.023404496,
#  'Loss/regularization_loss': 0.15359105,
#  'Loss/total_loss': 0.25955063,
#  'learning_rate': 0.032832485}
# I0621 07:10:35.213166 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.082555085,
#  'Loss/localization_loss': 0.023404496,
#  'Loss/regularization_loss': 0.15359105,
#  'Loss/total_loss': 0.25955063,
#  'learning_rate': 0.032832485}
# INFO:tensorflow:Step 8500 per-step time 0.556s
# I0621 07:11:30.818371 140686958434176 model_lib_v2.py:707] Step 8500 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.07192293,
#  'Loss/localization_loss': 0.01712993,
#  'Loss/regularization_loss': 0.15238072,
#  'Loss/total_loss': 0.24143358,
#  'learning_rate': 0.032621756}
# I0621 07:11:30.818678 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.07192293,
#  'Loss/localization_loss': 0.01712993,
#  'Loss/regularization_loss': 0.15238072,
#  'Loss/total_loss': 0.24143358,
#  'learning_rate': 0.032621756}
# INFO:tensorflow:Step 8600 per-step time 0.556s
# I0621 07:12:26.463211 140686958434176 model_lib_v2.py:707] Step 8600 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.06908578,
#  'Loss/localization_loss': 0.017688088,
#  'Loss/regularization_loss': 0.15001577,
#  'Loss/total_loss': 0.23678964,
#  'learning_rate': 0.032408677}
# I0621 07:12:26.463550 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.06908578,
#  'Loss/localization_loss': 0.017688088,
#  'Loss/regularization_loss': 0.15001577,
#  'Loss/total_loss': 0.23678964,
#  'learning_rate': 0.032408677}
# INFO:tensorflow:Step 8700 per-step time 0.556s
# I0621 07:13:22.045743 140686958434176 model_lib_v2.py:707] Step 8700 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.13453875,
#  'Loss/localization_loss': 0.026492136,
#  'Loss/regularization_loss': 0.14899202,
#  'Loss/total_loss': 0.3100229,
#  'learning_rate': 0.032193277}
# I0621 07:13:22.046075 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.13453875,
#  'Loss/localization_loss': 0.026492136,
#  'Loss/regularization_loss': 0.14899202,
#  'Loss/total_loss': 0.3100229,
#  'learning_rate': 0.032193277}
# INFO:tensorflow:Step 8800 per-step time 0.557s
# I0621 07:14:17.726974 140686958434176 model_lib_v2.py:707] Step 8800 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.0881701,
#  'Loss/localization_loss': 0.016167233,
#  'Loss/regularization_loss': 0.15043291,
#  'Loss/total_loss': 0.25477025,
#  'learning_rate': 0.03197561}
# I0621 07:14:17.727333 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.0881701,
#  'Loss/localization_loss': 0.016167233,
#  'Loss/regularization_loss': 0.15043291,
#  'Loss/total_loss': 0.25477025,
#  'learning_rate': 0.03197561}
# INFO:tensorflow:Step 8900 per-step time 0.557s
# I0621 07:15:13.449911 140686958434176 model_lib_v2.py:707] Step 8900 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.078785576,
#  'Loss/localization_loss': 0.018233906,
#  'Loss/regularization_loss': 0.14893961,
#  'Loss/total_loss': 0.24595909,
#  'learning_rate': 0.031755704}
# I0621 07:15:13.450291 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.078785576,
#  'Loss/localization_loss': 0.018233906,
#  'Loss/regularization_loss': 0.14893961,
#  'Loss/total_loss': 0.24595909,
#  'learning_rate': 0.031755704}
# INFO:tensorflow:Step 9000 per-step time 0.557s
# I0621 07:16:09.155681 140686958434176 model_lib_v2.py:707] Step 9000 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.06947226,
#  'Loss/localization_loss': 0.02722416,
#  'Loss/regularization_loss': 0.14671789,
#  'Loss/total_loss': 0.24341431,
#  'learning_rate': 0.031533606}
# I0621 07:16:09.156005 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.06947226,
#  'Loss/localization_loss': 0.02722416,
#  'Loss/regularization_loss': 0.14671789,
#  'Loss/total_loss': 0.24341431,
#  'learning_rate': 0.031533606}
# INFO:tensorflow:Step 9100 per-step time 0.576s
# I0621 07:17:06.787760 140686958434176 model_lib_v2.py:707] Step 9100 per-step time 0.576s
# INFO:tensorflow:{'Loss/classification_loss': 0.03846219,
#  'Loss/localization_loss': 0.011971716,
#  'Loss/regularization_loss': 0.1448072,
#  'Loss/total_loss': 0.19524111,
#  'learning_rate': 0.031309355}
# I0621 07:17:06.788179 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.03846219,
#  'Loss/localization_loss': 0.011971716,
#  'Loss/regularization_loss': 0.1448072,
#  'Loss/total_loss': 0.19524111,
#  'learning_rate': 0.031309355}
# INFO:tensorflow:Step 9200 per-step time 0.557s
# I0621 07:18:02.451021 140686958434176 model_lib_v2.py:707] Step 9200 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.08314316,
#  'Loss/localization_loss': 0.011705753,
#  'Loss/regularization_loss': 0.14305885,
#  'Loss/total_loss': 0.23790777,
#  'learning_rate': 0.031082997}
# I0621 07:18:02.451351 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.08314316,
#  'Loss/localization_loss': 0.011705753,
#  'Loss/regularization_loss': 0.14305885,
#  'Loss/total_loss': 0.23790777,
#  'learning_rate': 0.031082997}
# INFO:tensorflow:Step 9300 per-step time 0.557s
# I0621 07:18:58.103760 140686958434176 model_lib_v2.py:707] Step 9300 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.08309836,
#  'Loss/localization_loss': 0.015082475,
#  'Loss/regularization_loss': 0.14107199,
#  'Loss/total_loss': 0.23925282,
#  'learning_rate': 0.030854566}
# I0621 07:18:58.104109 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.08309836,
#  'Loss/localization_loss': 0.015082475,
#  'Loss/regularization_loss': 0.14107199,
#  'Loss/total_loss': 0.23925282,
#  'learning_rate': 0.030854566}
# INFO:tensorflow:Step 9400 per-step time 0.556s
# I0621 07:19:53.718809 140686958434176 model_lib_v2.py:707] Step 9400 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.07210773,
#  'Loss/localization_loss': 0.017622888,
#  'Loss/regularization_loss': 0.13880986,
#  'Loss/total_loss': 0.22854048,
#  'learning_rate': 0.030624112}
# I0621 07:19:53.719135 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.07210773,
#  'Loss/localization_loss': 0.017622888,
#  'Loss/regularization_loss': 0.13880986,
#  'Loss/total_loss': 0.22854048,
#  'learning_rate': 0.030624112}
# INFO:tensorflow:Step 9500 per-step time 0.557s
# I0621 07:20:49.377734 140686958434176 model_lib_v2.py:707] Step 9500 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.056637578,
#  'Loss/localization_loss': 0.0069734445,
#  'Loss/regularization_loss': 0.13661349,
#  'Loss/total_loss': 0.20022452,
#  'learning_rate': 0.030391678}
# I0621 07:20:49.378083 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.056637578,
#  'Loss/localization_loss': 0.0069734445,
#  'Loss/regularization_loss': 0.13661349,
#  'Loss/total_loss': 0.20022452,
#  'learning_rate': 0.030391678}
# INFO:tensorflow:Step 9600 per-step time 0.558s
# I0621 07:21:45.162880 140686958434176 model_lib_v2.py:707] Step 9600 per-step time 0.558s
# INFO:tensorflow:{'Loss/classification_loss': 0.08676522,
#  'Loss/localization_loss': 0.020707687,
#  'Loss/regularization_loss': 0.1346941,
#  'Loss/total_loss': 0.24216701,
#  'learning_rate': 0.030157303}
# I0621 07:21:45.163209 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.08676522,
#  'Loss/localization_loss': 0.020707687,
#  'Loss/regularization_loss': 0.1346941,
#  'Loss/total_loss': 0.24216701,
#  'learning_rate': 0.030157303}
# INFO:tensorflow:Step 9700 per-step time 0.556s
# I0621 07:22:40.786945 140686958434176 model_lib_v2.py:707] Step 9700 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.14315417,
#  'Loss/localization_loss': 0.021621058,
#  'Loss/regularization_loss': 0.13532342,
#  'Loss/total_loss': 0.30009866,
#  'learning_rate': 0.029921034}
# I0621 07:22:40.787298 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.14315417,
#  'Loss/localization_loss': 0.021621058,
#  'Loss/regularization_loss': 0.13532342,
#  'Loss/total_loss': 0.30009866,
#  'learning_rate': 0.029921034}
# INFO:tensorflow:Step 9800 per-step time 0.557s
# I0621 07:23:36.440240 140686958434176 model_lib_v2.py:707] Step 9800 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.05341701,
#  'Loss/localization_loss': 0.009830707,
#  'Loss/regularization_loss': 0.13386147,
#  'Loss/total_loss': 0.1971092,
#  'learning_rate': 0.029682912}
# I0621 07:23:36.440560 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.05341701,
#  'Loss/localization_loss': 0.009830707,
#  'Loss/regularization_loss': 0.13386147,
#  'Loss/total_loss': 0.1971092,
#  'learning_rate': 0.029682912}
# INFO:tensorflow:Step 9900 per-step time 0.556s
# I0621 07:24:32.021981 140686958434176 model_lib_v2.py:707] Step 9900 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.07990362,
#  'Loss/localization_loss': 0.013940739,
#  'Loss/regularization_loss': 0.13330694,
#  'Loss/total_loss': 0.22715129,
#  'learning_rate': 0.029442988}
# I0621 07:24:32.022338 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.07990362,
#  'Loss/localization_loss': 0.013940739,
#  'Loss/regularization_loss': 0.13330694,
#  'Loss/total_loss': 0.22715129,
#  'learning_rate': 0.029442988}
# INFO:tensorflow:Step 10000 per-step time 0.557s
# I0621 07:25:27.692836 140686958434176 model_lib_v2.py:707] Step 10000 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.0820529,
#  'Loss/localization_loss': 0.010536741,
#  'Loss/regularization_loss': 0.13189721,
#  'Loss/total_loss': 0.22448686,
#  'learning_rate': 0.029201299}
# I0621 07:25:27.693148 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.0820529,
#  'Loss/localization_loss': 0.010536741,
#  'Loss/regularization_loss': 0.13189721,
#  'Loss/total_loss': 0.22448686,
#  'learning_rate': 0.029201299}
# INFO:tensorflow:Step 10100 per-step time 0.573s
# I0621 07:26:24.984025 140686958434176 model_lib_v2.py:707] Step 10100 per-step time 0.573s
# INFO:tensorflow:{'Loss/classification_loss': 0.044728916,
#  'Loss/localization_loss': 0.011831559,
#  'Loss/regularization_loss': 0.13085534,
#  'Loss/total_loss': 0.18741581,
#  'learning_rate': 0.028957896}
# I0621 07:26:24.984381 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.044728916,
#  'Loss/localization_loss': 0.011831559,
#  'Loss/regularization_loss': 0.13085534,
#  'Loss/total_loss': 0.18741581,
#  'learning_rate': 0.028957896}
# INFO:tensorflow:Step 10200 per-step time 0.557s
# I0621 07:27:20.719364 140686958434176 model_lib_v2.py:707] Step 10200 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.060910556,
#  'Loss/localization_loss': 0.009868957,
#  'Loss/regularization_loss': 0.1304888,
#  'Loss/total_loss': 0.20126832,
#  'learning_rate': 0.028712818}
# I0621 07:27:20.719698 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.060910556,
#  'Loss/localization_loss': 0.009868957,
#  'Loss/regularization_loss': 0.1304888,
#  'Loss/total_loss': 0.20126832,
#  'learning_rate': 0.028712818}
# INFO:tensorflow:Step 10300 per-step time 0.556s
# I0621 07:28:16.357614 140686958434176 model_lib_v2.py:707] Step 10300 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.06269066,
#  'Loss/localization_loss': 0.01230096,
#  'Loss/regularization_loss': 0.1296168,
#  'Loss/total_loss': 0.20460841,
#  'learning_rate': 0.028466115}
# I0621 07:28:16.357923 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.06269066,
#  'Loss/localization_loss': 0.01230096,
#  'Loss/regularization_loss': 0.1296168,
#  'Loss/total_loss': 0.20460841,
#  'learning_rate': 0.028466115}
# INFO:tensorflow:Step 10400 per-step time 0.556s
# I0621 07:29:11.979738 140686958434176 model_lib_v2.py:707] Step 10400 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.07813131,
#  'Loss/localization_loss': 0.013647852,
#  'Loss/regularization_loss': 0.129271,
#  'Loss/total_loss': 0.22105017,
#  'learning_rate': 0.028217835}
# I0621 07:29:11.980120 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.07813131,
#  'Loss/localization_loss': 0.013647852,
#  'Loss/regularization_loss': 0.129271,
#  'Loss/total_loss': 0.22105017,
#  'learning_rate': 0.028217835}
# INFO:tensorflow:Step 10500 per-step time 0.557s
# I0621 07:30:07.633325 140686958434176 model_lib_v2.py:707] Step 10500 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.15051271,
#  'Loss/localization_loss': 0.032052267,
#  'Loss/regularization_loss': 0.1317475,
#  'Loss/total_loss': 0.31431246,
#  'learning_rate': 0.027968023}
# I0621 07:30:07.633646 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.15051271,
#  'Loss/localization_loss': 0.032052267,
#  'Loss/regularization_loss': 0.1317475,
#  'Loss/total_loss': 0.31431246,
#  'learning_rate': 0.027968023}
# INFO:tensorflow:Step 10600 per-step time 0.557s
# I0621 07:31:03.334680 140686958434176 model_lib_v2.py:707] Step 10600 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.06224949,
#  'Loss/localization_loss': 0.017334899,
#  'Loss/regularization_loss': 0.13264471,
#  'Loss/total_loss': 0.2122291,
#  'learning_rate': 0.027716719}
# I0621 07:31:03.335029 140686958434176 model_lib_v2.py:708] {'Loss/classification_loss': 0.06224949,
#  'Loss/localization_loss': 0.017334899,
#  'Loss/regularization_loss': 0.13264471,
#  'Loss/total_loss': 0.2122291,
#  'learning_rate': 0.027716719}

# %%
# !pip install tensorflow==2.8
# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.8
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.0%2Bzzzcolab20220506162203-cp37-cp37m-linux_x86_64.whl
#      / 668.3 MB 401 kB/s
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 31.7 MB/s
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.15.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (0.2.0)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 56.6 MB/s
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (0.26.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (3.1.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (14.0.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (3.3.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 71.9 MB/s
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (4.1.1)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.14.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (3.19.4)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (57.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.1.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.46.3)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.21.6)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.12)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow==2.8) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.28.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.12)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.0)
# Installing collected packages: tf-estimator-nightly, tensorboard, keras, tensorflow
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.1
#     Uninstalling tensorflow-2.9.1:
#       Successfully uninstalled tensorflow-2.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-models-official 2.9.2 requires tensorflow~=2.9.0, but you have tensorflow 2.8.0+zzzcolab20220506162203 which is incompatible.
# tensorflow-text 2.9.0 requires tensorflow<2.10,>=2.9.0; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.8.0+zzzcolab20220506162203 which is incompatible.
# Successfully installed keras-2.8.0 tensorboard-2.8.0 tensorflow-2.8.0+zzzcolab20220506162203 tf-estimator-nightly-2.8.0.dev2021122109
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following packages will be REMOVED:
#   libcudnn8-dev
# The following held packages will be changed:
#   libcudnn8
# The following packages will be upgraded:
#   libcudnn8
# 1 upgraded, 0 newly installed, 1 to remove and 47 not upgraded.
# Need to get 430 MB of archives.
# After this operation, 3,139 MB disk space will be freed.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcudnn8 8.1.0.77-1+cuda11.2 [430 MB]
# Fetched 430 MB in 6s (66.2 MB/s)
# (Reading database ... 155639 files and directories currently installed.)
# Removing libcudnn8-dev (8.0.5.39-1+cuda11.1) ...
# (Reading database ... 155617 files and directories currently installed.)
# Preparing to unpack .../libcudnn8_8.1.0.77-1+cuda11.2_amd64.deb ...
# Unpacking libcudnn8 (8.1.0.77-1+cuda11.2) over (8.0.5.39-1+cuda11.1) ...
# Setting up libcudnn8 (8.1.0.77-1+cuda11.2) ...

# %%
# !pip uninstall opencv-python
# Out:
# Found existing installation: opencv-python 4.1.2.30
# Uninstalling opencv-python-4.1.2.30:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/cv2/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python-4.1.2.30.dist-info/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.7/dist-packages/cv2/config-3.py
#     /usr/local/lib/python3.7/dist-packages/cv2/config.py
#     /usr/local/lib/python3.7/dist-packages/cv2/cv2.abi3.so
#     /usr/local/lib/python3.7/dist-packages/cv2/gapi/__init__.py
#     /usr/local/lib/python3.7/dist-packages/cv2/load_config_py2.py
#     /usr/local/lib/python3.7/dist-packages/cv2/load_config_py3.py
#     /usr/local/lib/python3.7/dist-packages/cv2/mat_wrapper/__init__.py
#     /usr/local/lib/python3.7/dist-packages/cv2/misc/__init__.py
#     /usr/local/lib/python3.7/dist-packages/cv2/misc/version.py
#     /usr/local/lib/python3.7/dist-packages/cv2/utils/__init__.py
#     /usr/local/lib/python3.7/dist-packages/cv2/version.py
# Proceed (y/n)? y
#   Successfully uninstalled opencv-python-4.1.2.30

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      |████████████████████████████████| 60.9 MB 1.1 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.21.6)
# Installing collected packages: opencv-python
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed opencv-python-4.6.0.66
